# %%
# !pip install PyDrive
# Out:
# Collecting PyDrive
#   Downloading https://files.pythonhosted.org/packages/52/e0/0e64788e5dd58ce2d6934549676243dc69d982f198524be9b99e9c2a4fd5/PyDrive-1.3.1.tar.gz (987kB)
#      |████████████████████████████████| 993kB 4.7MB/s
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.12.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.5)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.5)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Building wheels for collected packages: PyDrive
#   Building wheel for PyDrive (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# Installing collected packages: PyDrive
# Successfully installed PyDrive-1.3.1

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
from pydrive.auth import GoogleAuth
auth.authenticate_user()
gauth = GoogleAuth()

# %%
drive = GoogleDrive(gauth)

# %%
gauth.credentials = GoogleCredentials.get_application_default()

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '1BgkNLDFEbH9IH6i-fQ4dNNlSXC212wjN'})

# %%
download.GetContentFile('DOWNLOAD.json')

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df=pd.read_json('DOWNLOAD.json', lines=True)

# %%
df1=df
df2=df
df
# Out:
#       accessedResources  adblockerStatus  ... userAgent                   visitId
# 0                    []                0  ...       dwc  epKCqTEn23Hzv4ux1+rRGg==
# 1                    []                0  ...       dwi  SDS1ZZi0IwQirrj87f5QZQ==
# 2                    []                0  ...       mim  VDeprRCrVjrm0tKgQr5Ljg==
# 3                    []                0  ...       dwc  yBe9NTZO043gn5xXSnXXcQ==
# 4                    []               -1  ...       dwf  TN5kiq+OaUyn0/UHZnUQRA==
# 5                    []                0  ...       dms  9IY1hZo3emSBdUoaktC4nQ==
# 6                    []                0  ...       mac  C2X1rR7mBOrAhBmhdvX4Jg==
# 7                    []                0  ...       mac  6BlFHnJejO2wrIQsjpOhfg==
# 8                    []                0  ...       dwf  WOg5ssN7R7qLOpvpP7SmxA==
# 9                    []                0  ...       dwf  UjbfpG87MInRkUFSa4KZqA==
# 10                   []                0  ...       dwc  y/G0bFUEGoJY5M8L8nLb0A==
# 11                   []                0  ...       mac  OsJnvCHVaYy9C/Eq2c9J6w==
# 12                   []                0  ...       mis  Xg/I8JdYIiCFK72cS6eFFw==
# 13                   []                0  ...       dmc  dVbzOiyjwxu35Lzh8seRcg==
# 14                   []                0  ...       dwc  7zBX7oH+1e6QgSwtXQGK2g==
# 15                   []                0  ...       tis  yfSMb9aXicQYwSuNSe2VvA==
# 16                   []                0  ...       dwc  8cUG8lJVHlDjF0qbD0DJjQ==
# 17                   []                0  ...       dwi  0KXUDCZeAfSl8+P2+vOeqg==
# 18                   []                0  ...       mis  IFG3AacXKivINhg91+vqGg==
# 19                   []                0  ...       dwc  h+ucUBiLXMvcbXZNoauMaA==
# 20                   []                0  ...       dwc  fhyQLbo9KlltI0+Asbfsnw==
# 21                   []                0  ...       dwc  BdPDs/1jg7YYsfetOfQUJw==
# 22                   []                0  ...       mac  Jq6bJgS6LbMKQtbozYxqoQ==
# 23                   []                0  ...       mac  Eyz5z0sv2mCgeh8UtRslgA==
# 24                   []                0  ...       dwf  jCj8C8jOz0mp9vnM/zDTWw==
# 25                   []                0  ...       mis  +v15I2KFBOGBWUy2G1X9qg==
# 26                   []                0  ...       dwf  jwFfaABlUZ8Wx25aWfiJ1g==
# 27                   []                0  ...       bob  xVYwzDtJSGy0IlsLu0ijPw==
# 28                   []                0  ...       mis  oLd1WLwho2MVJMsUGUjCAg==
# 29                   []                0  ...       doc  CXvBaC63/L5WEa4zyxhy+w==
# ...                 ...              ...  ...       ...                       ...
# 49970                []                0  ...       mis  dsRJ+IxlxaKq1erH0xmmWA==
# 49971                []                0  ...       dwc  pjl6HRWg5pVrVgkuCVIC9g==
# 49972                []                0  ...       dwc  pjl6HRWg5pVrVgkuCVIC9g==
# 49973                []               -1  ...       dwf  UeoKS/LwJbPILy/IaeLhSA==
# 49974                []                0  ...       dwc  y4CBwYG4VlnEctPHZX16Xw==
# 49975                []                1  ...       dwc  VuutaPyZbZaN5DQRoMU02A==
# 49976                []                0  ...       dms  MuEjFBghtOs59gLTEMplkw==
# 49977                []                0  ...       dwc  gXpgu+GPcStNWfGc+pmEnA==
# 49978                []                0  ...       dwi  5t+O4kJzuh+ZuqlZFb3hOg==
# 49979                []                1  ...       bob  uekG89SZWQlJvYUv05VynQ==
# 49980                []                0  ...       dwc  wB/0y+KUbcDPP99Em+oePw==
# 49981                []                0  ...       dms  /sA/ksYXGtY3N3KBKstiug==
# 49982                []               -1  ...       dwc  AB+rNO9AuniLcPBanz8/pQ==
# 49983                []                0  ...       mis  iVbxXoSuyVoG2I5A1j1D6Q==
# 49984                []                0  ...       mim  LT0tUhD+ri5Gyhbw7QNgvQ==
# 49985                []                1  ...       dwc  v63iFNT4MthQ51jr6TBToA==
# 49986                []                0  ...       dwf  ggwUnOjE0IUwHVKVFj3lSg==
# 49987                []               -1  ...       mis  kxHtxdZkp6fCGanVQIZYvg==
# 49988                []                0  ...       dwi  thxTlZxGBTDTmSbj+sJfkA==
# 49989                []                0  ...       dwf  qHUTFCDb0GzZVRWHrkj8Wg==
# 49990                []                0  ...       dmc  bUm0CICUeN0Q7AbNf4zfZA==
# 49991                []                0  ...       dwf  8Vvj6BcthCy8WnuPXUKWqg==
# 49992                []               -1  ...       mac  fBRUX4li4YQyn3Ux8aZrnw==
# 49993                []                0  ...       dwc  zradKVIGt4in9/pAO6S/HQ==
# 49994                []                0  ...       dwc  lnI/TSlZx9iSUXub2xLgeA==
# 49995                []                0  ...       dwc  6jmYkR96gMQmL+K35GGnmw==
# 49996                []                1  ...       dwc  CIDswCDYmGaKyURT8Y18oA==
# 49997                []                0  ...       dwf  At/wO0tqY76Y5MW4KNG3JQ==
# 49998                []                0  ...       dwc  MWOjpnsa2U2fnT2yAFgvag==
# 49999                []                0  ...       dwc  5lLnEogvobcapjHLE8SYkQ==
#
# [50000 rows x 48 columns]

# %%
df['unixTimestamp']=(pd.to_datetime(df['unixTimestamp']))

df['d'] = df['unixTimestamp'].dt.day
df = df.groupby(['d','browserId'])['unixTimestamp'].count().reset_index(name="freq")

result = df[df.freq >= 2]

# only user ids matching criteria
user_ids = result.browserId.tolist()
print(user_ids)
retention = df1['browserId'].isin(user_ids)
df1['Ret'] = '0'
df1['Ret']=retention
dfpure=df1.drop_duplicates(subset=['browserId'], keep='first')
dfpure.groupby(['Ret']).sum()
dfpure=df1.drop_duplicates(subset=['browserId'], keep='first')
dfpure.drop(dfpure.loc[dfpure['isFirstVisit']==False].index, inplace=True)
# Out:
# ['++0ql4dIZ6xbkzzqjvwZ4A==', '++HEkBlWuIQlkp/hfXDJ9w==', '+/LA928OlJT6VRLd34BhDQ==', '+/Md2UxKm27JVuqFn7tnZg==', '+/P9shIzNgFObJNu3JNssw==', '+/dOncDhx8YEQZ4XZ8p9cA==', '+02WXqSnY/csUmw8Uq+/Tg==', '+07FZ3OTOBHBILKm2wW3/A==', '+0gYX/rElRfkOwaSedzKLQ==', '+0myJicU7StBktpC8/9ECw==', '+2F7yESSpVw/BirbJuyDNQ==', '+2pgqgbdqrYEZxvA+oTtBA==', '+33vYqDXW9VmwKmiX7AajQ==', '+3AvnExG/DGr41HlPgeawg==', '+3SppkZKKrVEj11xEaOJcw==', '+3Zoccre+ujQMCbiDo/ang==', '+3cQlYRvN3w1Q/ECL9VKIA==', '+4QP4SqoYaJm1FBHZYGgrg==', '+4TWRg1wR/YcfnEPqjA5Aw==', '+4o+cXuckhj7fIilFZeVtg==', '+4vki79iphQAilMt6YMmYg==', '+4xn8HjOuGz8udr4nCR7tA==', '+5+osr3aInid1OSA3Z7g1A==', '+55Eisurb0we3WuH7oZnLw==', '+6DcqruH18lF2LfffPbpSg==', '+6KJ4WUdkI5DQnRxSkbOEQ==', '+6at1HgvwK5AY/D9knQjaQ==', '+84IxgiVKN0atIUNvtUAiw==', '+90OwhcKJ9SLQko5mTLPlA==', '+9CM8MABldlGeSB8t8e5Qg==', '+9CTmSCkENcvUntFrbiuKQ==', '+9LOahASGor1f9qH45UFtQ==', '+A0iubbHTcrcpLmEm+otwg==', '+ABtn7Q2fzRTNA0+hLidPg==', '+AKF4IFXpcuvZk0RJbqkyQ==', '+AMmPwAdZRSLGdksBKOqfw==', '+BaFzaS5EC/fRr20HOQjVQ==', '+BcdVl0JfZ3c+aQh4RmM1A==', '+C2kT9am98ssf4yACjTTKw==', '+CktgjiUKVlj2QywdoCizQ==', '+Cv6yEAzEathtP0vSTUbCg==', '+DT69U4VTebv6ZhoWApVxw==', '+DrgZEcKnbEbV+7lhaRnuA==', '+EUFy2QMHVCG73IkKFcNJg==', '+EUojrE+gEitTlD8rTHDzg==', '+Eh52Ajm+MmbrwDYf5QwTw==', '+Em23m0gGjCcFTumnj2LIQ==', '+FMj4CPRMymKljCPr29zbg==', '+FMuctSpJocjrsxaK6dp3w==', '+Fg4UU6HkjxRQ8wsw87JcA==', '+G6krn7mEpfrNCPmYLbybQ==', '+GSz1tO4gMD2dlZ555TSsQ==', '+GsWAEbIX079fVqsaRePmg==', '+HGu+vt3cJeClXAVdq8kzA==', '+I9DFU1sttamaCH0mDYvXg==', '+IZGSmwNzT+acNs7f7IQAA==', '+IoTkKrfckP6LoNpGAx0MQ==', '+JbK5Z3leVVXSgGhWZ0kaw==', '+JloBKskw3iptVgB8OGXDw==', '+K5ccalNzuRCN9huwQoPEA==', '+KQdL5mB82Ymitnres/FUA==', '+KifGArF04a+Ro1FJyjm9Q==', '+Kur/mZpHEBFKJY6GRpr3A==', '+L0NAo9I1gFBUZthB2V0nw==', '+LBaiJFGqB0etxx8hi7kLg==', '+LIvZsn0n0Rnx0boLFzZmg==', '+Lo4FBYlRjak5zZC7qYMqg==', '+MGe1E1F4KwLK035R+TOMg==', '+MkUa3CzuRQ1w7XJ+jDLZg==', '+NAQFYCNLiy8UyZxuDWIIA==', '+NnrBOl1iWAHqG6YWj+fhQ==', '+O+YN1xTs+r2kkucmnlaXQ==', '+Oxn6fv3AeqOkrkUuVZOrA==', '+PSoP7f2aBIO71e8z9B77w==', '+PVX2yP4IVhcEimLxQeVBg==', '+QrD8Opxc6rpNCrmtw/ing==', '+QtNuhl/NvHy43aTNaa5TA==', '+RaVb+2LCf/x2tOnjyP4kA==', '+SXiuEg9EZKv8cV0MQC4vw==', '+SjXzIddqZ8v+PsQBRKjDQ==', '+T9YueMNxk7J4UqFtHxfDA==', '+TdPFh2WubWDTCgHbUDkuw==', '+TdSM/jM0d/3klosLxoeWg==', '+TudwLJcEWJF99GEi71gYQ==', '+UOJpShLCjNydlGRl7gJ+Q==', '+UeIJ66sctLfosrfCmUobQ==', '+VII6rDXzW2vS/QFJPsvXg==', '+VJQgUii6h6Eigx9yMeeow==', '+VrD7MaWVCSu18HsHY+Mew==', '+VroO+oRtkrzDzuKdls7UA==', '+W0MFlmVbTVh5KAISMpHJQ==', '+WQg9eJg4ihLwu0lzaL/Gg==', '+WZuMcRisF4ifm28B+Xp6g==', '+Wlk4TNPZzwpoz6Z1UmIxg==', '+X4FbTHBVn5yqc7Vl4QnlA==', '+XECkC9yK702WdO0WUMxkA==', '+XNbf2CHnmXAPR1/aV6PTQ==', '+XmSIdLOJmHCVwAu1o0XZw==', '+XxmGVqB7PP6Cr7tdIJkqw==', '+YRgBBg35Xthbv8MSTtMmQ==', '+YSHGaBUa+l2BKz9KdxcDQ==', '+ZBmX6CfM6zSbVdn3qw7QA==', '+Zc0KV54j/4Tg8eAhzWuBA==', '+a8fta8/V6oqb6qBXQJjQQ==', '+aBPnk9XTGHHkgpeR3ujRQ==', '+alUd7RJS4DpYiqrbeoozQ==', '+bYGJpqfqLdLksNi2JsEOA==', '+bkCqwHmutu+T1axgvVC3w==', '+br/HO67olgHo10hr90mbg==', '+cMYQa3tybU5SS4ZzxSDEA==', '+d9r86IesXcrhSM5aNjF2g==', '+diDKfwI2BeLW3i13Uuqkg==', '+dvi+Fgx9EH5TqQ03XHw1g==', '+e1nzwhOmss9Hmu+1lpKfg==', '+e9ujaptprdwoosYCnd4SA==', '+eXCAQ0GdkPDexs156yCRA==', '+el7n+aRdIyUltCpbCny3Q==', '+eww9Z1MkWTSw4vLhcZUgA==', '+f78WbB7Jhe8uGL32cIXqg==', '+fDbxJw8X9OfuSTut19KMQ==', '+fv/w0Ex5jARptuh2+lUzA==', '+gTJKcNv2gep/hIhPMT8Ag==', '+gWKso8iPHaQZucXO4lqiA==', '+gs5ZX7x5HRsO/cIlNgxRg==', '+hfTl3X/PrmMjc1CHhsl6Q==', '+i6FP6T21a9n4BvxkOKqrQ==', '+ima3KjtkpnUX4EceiCBQg==', '+jAFaz5hfd/zc2KbV+vMaQ==', '+jVcmcTxbW+xurL+frmIPA==', '+k5SUcYLiUkHWTt7ozIypw==', '+kJ5H8ojcLZAEo0guOPNAA==', '+l/utWHivkdgO4TQEQM/tQ==', '+l6PJnSWOaVDD6BzeoQoAA==', '+l9Tv0zinmC2mS3k3Zujxg==', '+lqVsVcejuSnSTLQPQovGw==', '+ltCqUhDsmGpvZ1ubVfSdg==', '+m2sBCifjJpXz0e72hq4zQ==', '+mLPtHYVG4UNsiX9uL/x+A==', '+miA4s1BsSupmQfhFKWfeQ==', '+n1Xccj6MCZpdNzO0zP5pQ==', '+nWVWY7iO18EKUVDpE6ksQ==', '+nZ40jvS6Quk7O6EP+ziRA==', '+oon87PGb50KkWDTEaGpbg ...
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
retention = df1['browserId'].isin(user_ids)
df1['Ret'] = '0'

# %%
df1['Ret']=retention

# %%
dfpure=df1.drop_duplicates(subset=['browserId'], keep='first')

# %%
dfpure.groupby(['Ret']).sum()
# Out:
#        adblockerStatus  dmaCode  ...  timezoneOffset     d
# Ret                              ...
# False              340  3679948  ...        -2320530  8826
# True              -353   973259  ...         -546480  2044
#
# [2 rows x 12 columns]

# %%
dfpure
# Out:
#       accessedResources  adblockerStatus  ...  d    Ret
# 2                    []                0  ...  1  False
# 5                    []                0  ...  1   True
# 8                    []                0  ...  1  False
# 10                   []                0  ...  1  False
# 11                   []                0  ...  1  False
# 12                   []                0  ...  1  False
# 15                   []                0  ...  1  False
# 24                   []                0  ...  1  False
# 25                   []                0  ...  1  False
# 26                   []                0  ...  1  False
# 27                   []                0  ...  1  False
# 40                   []               -1  ...  1   True
# 41                   []                0  ...  1  False
# 43                   []                0  ...  1  False
# 58                   []                0  ...  1  False
# 64                   []                0  ...  1  False
# 65                   []                0  ...  1  False
# 66                   []                0  ...  1  False
# 70                   []                0  ...  1  False
# 77                   []                0  ...  1  False
# 78                   []                0  ...  1  False
# 83                   []                0  ...  1  False
# 84                   []                0  ...  1  False
# 85                   []                0  ...  1   True
# 86                   []                0  ...  1  False
# 89                   []                0  ...  1  False
# 90                   []                0  ...  1  False
# 92                   []                0  ...  1  False
# 98                   []                0  ...  1  False
# 99                   []                0  ...  1  False
# ...                 ...              ...  ... ..    ...
# 49870                []                0  ...  1  False
# 49880                []                0  ...  1  False
# 49881                []                0  ...  1  False
# 49886                []                0  ...  1  False
# 49892                []                0  ...  1  False
# 49897                []                0  ...  1  False
# 49899                []                0  ...  1  False
# 49901                []                1  ...  1  False
# 49902                []                0  ...  1  False
# 49918                []                0  ...  1  False
# 49919                []                0  ...  1  False
# 49921                []                0  ...  1  False
# 49922                []                0  ...  1  False
# 49936                []                0  ...  1  False
# 49937                []                1  ...  1  False
# 49943                []                0  ...  1  False
# 49944                []                0  ...  1  False
# 49945                []                0  ...  1  False
# 49948                []                0  ...  1  False
# 49950                []                0  ...  1  False
# 49952                []                0  ...  1  False
# 49954                []               -1  ...  1  False
# 49958                []               -1  ...  1  False
# 49965                []                0  ...  1  False
# 49969                []                0  ...  1  False
# 49973                []               -1  ...  1  False
# 49982                []               -1  ...  1  False
# 49984                []                0  ...  1  False
# 49995                []                0  ...  1  False
# 49999                []                0  ...  1  False
#
# [10870 rows x 50 columns]

# %%
pd.isna(dfpure).sum() #counting NaN
# Out:
# accessedResources       0
# adblockerStatus         0
# aid                     0
# browser                 0
# browserId               0
# city                 1188
# content                 0
# contentAuthor           0
# contentCreated       1258
# contentSection          0
# country                 0
# countryCode             5
# customParamList         0
# customParams            0
# dmaCode                 0
# fingerprint             0
# globalBrowserId         0
# hasAccess               0
# hour                    0
# ip                      0
# isFirstVisit            0
# isNewVisit              0
# newsletter              0
# node                    0
# operatingSystem         0
# originalUrl             0
# pageSessionId           0
# pageViewId              0
# parsedReferrer          0
# parsedReferrerId        0
# platform                0
# rawReferrer             0
# rawUserAgent            0
# referrerSegment         0
# referrerSegmentId       0
# region               1152
# resourceIds             0
# sailthruCookie          0
# source                  0
# submissionCount         0
# submitType              0
# tags                    0
# timezoneOffset          0
# uid                     0
# unixTimestamp           0
# url                     0
# userAgent               0
# visitId                 0
# d                       0
# Ret                     0
# dtype: int64

# %%
dfauth=dfpure.groupby('contentAuthor').sum()

# %%
# sorting w.r.t name column 
dfauth.sort_values("isNewVisit", na_position = 'last') 
dfauth.iloc[::-1]
dfauth
# Out:
#                           adblockerStatus  dmaCode  ...    d   Ret
# contentAuthor                                       ...
# +9o9hW76vjAM3iA6sAvXzg==                0     5249  ...   11   1.0
# +JIx4Nypl123rOsgL8OUfA==                0      511  ...    1   0.0
# +VpaBcaysFqukfCrx0ikuA==                0      512  ...    4   0.0
# +blLmk+s2fCNHBc088yAew==                0     2365  ...    3   1.0
# +fr7QezbyuXNEacMaSWpbA==                0        0  ...    1   0.0
# +iF68Bgte0Q+5eH0T1A68g==               -4    18298  ...   48   9.0
# +jzn9Vr6IDFbGB5rF3yN/Q==                0      501  ...    1   1.0
# +ugVRX2Ib2/l9rav3fzwhA==                0      582  ...    1   0.0
# //IWnV7aPEyDLFucPISamQ==                0        0  ...    2   0.0
# /1FbE1H/0jo8WaJfVsH2QA==                0      533  ...    1   0.0
# /8h4Wf/a2mtddz4gTnwQaw==                1     3363  ...   11   1.0
# /8l8YiCsyPWMkKKG35hnpw==                3     9269  ...   24   0.0
# /GO/+S3miZ8DEpevW+CVDQ==               -1        0  ...    1   0.0
# /VIwHJ9lcnG/wqr4N2r1Vw==                0      790  ...    1   0.0
# /W1YptieosjcF0UN5n62+g==                0     1405  ...    5   1.0
# /kZAytLQrjADIJJ+AqPN6g==                0      807  ...    1   0.0
# /yIrdkESA2+5UHEIqJ/lZQ==                0     2128  ...    4   0.0
# 0/hFRr6bpv00ydQcDt3Cjg==                0      511  ...    1   0.0
# 088i1FztxAojO7Pgx2TBug==                0        0  ...    1   0.0
# 0DfkqiYzScU0vq7Sxk0hQQ==                0      511  ...    1   0.0
# 0ILiu99VvhI3dF514SaReQ==                0    16948  ...   37   7.0
# 0OFl0k77t86vsG9iQ/yBOA==                0      810  ...    1   0.0
# 0RBaHlTLvfOcXTQSAPeGmQ==                0     4794  ...    9   1.0
# 0S2iG9jYWnmPMsQJ+Z4QMQ==                0     1139  ...   12   0.0
# 0Ti7Kvs+Y4Tw7DaOIYCnvg==                1        0  ...    1   1.0
# 0Titfx842NnjxSRZDYKowQ==                0        0  ...    1   0.0
# 0ofgjZ1mmpI/Lojgdr8oSA==               -1     9720  ...   43   5.0
# 0rkwfssai+eL9xnfVIuaaA==                0        0  ...    1   0.0
# 0zQ7rGtt7hihJIQ58MPu3g==                0      744  ...    2   1.0
# 14Hg+bk0SbRm/4XTBrpXiA==                0      517  ...    1   1.0
# ...                                   ...      ...  ...  ...   ...
# w8JHdLUSywotL1EI7OvAyA==                0        0  ...    1   0.0
# wA2wFNY6/FNDqLCJst9uWQ==                0      643  ...    1   0.0
# wNkGVyF/hIPiedQPFbjbsA==                0        0  ...    1   0.0
# wdOTaqRW69a8iDj8BShhkg==                3    17591  ...   37   6.0
# wjXy6jWxozy+VdsF4HCqVw==               -5    54835  ...  108   7.0
# wraVM9ucgErkLr2+nVoltQ==                0        0  ...    1   0.0
# wt0O735CEFbqmMYJ/elkaw==                0        0  ...    1   0.0
# x0VvxK3DWOsu3QGUalUovw==                0        0  ...    1   0.0
# x0bogxXA5h3KgHL6ZLZNzw==                0      505  ...    1   0.0
# x7aCpk459PbmxWWhXAo0eg==                0      803  ...    2   0.0
# xEdmYvhMrpswSmyT1FRVBA==                0     1556  ...    4   0.0
# xG8lJw2JPfOKmRIHkELCgg==                0     1254  ...    2   2.0
# xKa7QznAoqjbmjXqyBvAnA==                0     1061  ...    3   0.0
# xVJaOBMAhpPcfTm2HeseLA==                0        0  ...    1   0.0
# xcN+w21rV1I3DdVsW5Fmdg==               -3     5473  ...   12   2.0
# yA96zm/O7ewq/JYc3BTilA==                0        0  ...    1   0.0
# yTIlYxpO+v+PMPXmGlXOkA==                0      511  ...    1   0.0
# yXuiNKOEJ+T8rTA6jbwVlw==                0        0  ...    1   0.0
# yZnt3PG6YAGJR+/6Q3IySg==               10    81319  ...  168  27.0
# yiMDQ1HmpYMYp5maH/UMpA==                0        0  ...    1   0.0
# ykpDXee8u7f0OZvM4sygzg==               -4     3022  ...    8   5.0
# yo3/5hLPF4ti8d6a+1Hb6w==                0      571  ...    1   0.0
# youtU+OoLXGRccQ6BfWScg==                0      765  ...    4   0.0
# z8acicSOyBpnBv+zafgl0Q==                1        0  ...    1   1.0
# zQTkbd0a0ZZ5lQ1+uBFQ/A==                0        0  ...    1   0.0
# zTNR/S8rmQ0ymZ9HGXx6eQ==                0        0  ...    1   0.0
# zU66r2nyF6ZFiTDYibmeMg==               -1      511  ...    1   1.0
# znIVIyCjW21WbiPR2maBjA==                0      820  ...    2   0.0
# zsQhmJy0lgh3YDdr4X60uA==                0        0  ...    1   0.0
# zzz0PM+HgyC3oc4e1F+eIg==                0     3340  ...    6   0.0
#
# [592 rows x 13 columns]

# %%
dfpure.drop(dfpure.loc[dfpure['isFirstVisit']==False].index, inplace=True)

# %%
import featuretools as ft

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression

# %%
df_majority = dfpure[dfpure['Ret']==False] #balancing our dataset
df_minority = dfpure[dfpure['Ret']==True]
# Upsample minority class

from sklearn.utils import resample
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     
                                 n_samples=8826, random_state=123)   
df_up = pd.concat([df_majority, df_minority_upsampled])
df_up['Ret'].value_counts()
# Out:
# True     8826
# False    8826
# Name: Ret, dtype: int64

# %%
X = df_up['contentAuthor']
Y = df_up['Ret']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33)
cvec = CountVectorizer(stop_words='english').fit(X_train)
df_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
df_test=pd.DataFrame(cvec.transform(X_test).todense(), columns=cvec.get_feature_names())
a_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())

# %%
lr = LogisticRegression(penalty='l1')
lr.fit(df_train, Y_train)
lr.score(df_test, Y_test)
# Out:
# 0.6338825952626158

# %%
lr = LogisticRegression()
lr.fit(df_train, Y_train)
lr.score(df_test, Y_test)
# Out:
# 0.6409200137315483

# %%
pd.get_dummies(dfpure['contentAuthor'])
# Out:
#        +9o9hW76vjAM3iA6sAvXzg==  ...  zzz0PM+HgyC3oc4e1F+eIg==
# 2                             0  ...                         0
# 5                             0  ...                         0
# 8                             0  ...                         0
# 10                            0  ...                         0
# 11                            0  ...                         0
# 12                            0  ...                         0
# 15                            0  ...                         0
# 24                            0  ...                         0
# 25                            0  ...                         0
# 26                            0  ...                         0
# 27                            0  ...                         0
# 40                            0  ...                         0
# 41                            0  ...                         0
# 43                            0  ...                         0
# 58                            0  ...                         0
# 64                            0  ...                         0
# 65                            0  ...                         0
# 66                            0  ...                         0
# 70                            0  ...                         0
# 77                            0  ...                         0
# 78                            0  ...                         0
# 83                            0  ...                         0
# 84                            0  ...                         0
# 85                            0  ...                         0
# 86                            0  ...                         0
# 89                            0  ...                         0
# 90                            0  ...                         0
# 92                            0  ...                         0
# 98                            0  ...                         0
# 99                            0  ...                         0
# ...                         ...  ...                       ...
# 49870                         0  ...                         0
# 49880                         0  ...                         0
# 49881                         0  ...                         0
# 49886                         0  ...                         0
# 49892                         0  ...                         0
# 49897                         0  ...                         0
# 49899                         0  ...                         0
# 49901                         0  ...                         0
# 49902                         0  ...                         0
# 49918                         0  ...                         0
# 49919                         0  ...                         0
# 49921                         0  ...                         0
# 49922                         0  ...                         0
# 49936                         0  ...                         0
# 49937                         0  ...                         0
# 49943                         0  ...                         0
# 49944                         0  ...                         0
# 49945                         0  ...                         0
# 49948                         0  ...                         0
# 49950                         0  ...                         0
# 49952                         0  ...                         0
# 49954                         0  ...                         0
# 49958                         0  ...                         0
# 49965                         0  ...                         0
# 49969                         0  ...                         0
# 49973                         0  ...                         0
# 49982                         0  ...                         0
# 49984                         0  ...                         0
# 49995                         0  ...                         0
# 49999                         0  ...                         0
#
# [10870 rows x 592 columns]

# %%
dfna=dfpure.dropna()
dfna
# Out:
#       accessedResources  adblockerStatus  ...  d    Ret
# 2                    []                0  ...  1  False
# 5                    []                0  ...  1   True
# 8                    []                0  ...  1  False
# 10                   []                0  ...  1  False
# 11                   []                0  ...  1  False
# 12                   []                0  ...  1  False
# 15                   []                0  ...  1  False
# 24                   []                0  ...  1  False
# 25                   []                0  ...  1  False
# 26                   []                0  ...  1  False
# 41                   []                0  ...  1  False
# 64                   []                0  ...  1  False
# 77                   []                0  ...  1  False
# 78                   []                0  ...  1  False
# 83                   []                0  ...  1  False
# 84                   []                0  ...  1  False
# 86                   []                0  ...  1  False
# 90                   []                0  ...  1  False
# 92                   []                0  ...  1  False
# 98                   []                0  ...  1  False
# 99                   []                0  ...  1  False
# 102                  []                0  ...  1  False
# 106                  []                0  ...  1  False
# 107                  []                0  ...  1  False
# 110                  []                0  ...  1  False
# 117                  []                0  ...  1  False
# 143                  []                0  ...  1  False
# 152                  []                0  ...  1  False
# 161                  []                0  ...  1  False
# 166                  []                0  ...  1  False
# ...                 ...              ...  ... ..    ...
# 49803                []                0  ...  1  False
# 49814                []                0  ...  1  False
# 49820                []                0  ...  1  False
# 49835                []                0  ...  1  False
# 49839                []                0  ...  1  False
# 49845                []                0  ...  1  False
# 49849                []                0  ...  1  False
# 49853                []                0  ...  1  False
# 49854                []                0  ...  1  False
# 49862                []                0  ...  1  False
# 49881                []                0  ...  1  False
# 49892                []                0  ...  1  False
# 49899                []                0  ...  1  False
# 49901                []                1  ...  1  False
# 49918                []                0  ...  1  False
# 49919                []                0  ...  1  False
# 49921                []                0  ...  1  False
# 49922                []                0  ...  1  False
# 49937                []                1  ...  1  False
# 49943                []                0  ...  1  False
# 49944                []                0  ...  1  False
# 49945                []                0  ...  1  False
# 49948                []                0  ...  1  False
# 49950                []                0  ...  1  False
# 49952                []                0  ...  1  False
# 49965                []                0  ...  1  False
# 49969                []                0  ...  1  False
# 49984                []                0  ...  1  False
# 49995                []                0  ...  1  False
# 49999                []                0  ...  1  False
#
# [8336 rows x 50 columns]

# %%
X = df_up['contentAuthor']
Y = df_up['Ret']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33)
cvec = CountVectorizer(stop_words='english').fit(X_train)
df_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
df_test=pd.DataFrame(cvec.transform(X_test).todense(), columns=cvec.get_feature_names())
a_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
lr = LogisticRegression()
lr.fit(df_train, Y_train)
lr.score(df_test, Y_test)
# Out:
# 0.6440096120837624

# %%
X = df_up['contentAuthor']
Y = df_up['Ret']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33)
cvec = CountVectorizer(stop_words='english').fit(X_train)
df_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
df_test=pd.DataFrame(cvec.transform(X_test).todense(), columns=cvec.get_feature_names())
a_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
lr = LogisticRegression(penalty='l1')
lr.fit(df_train, Y_train)
lr.score(df_test, Y_test)
# Out:
# 0.625643666323378

# %%
dfna
# Out:
#       accessedResources  adblockerStatus  ...  d    Ret
# 2                    []                0  ...  1  False
# 5                    []                0  ...  1   True
# 8                    []                0  ...  1  False
# 10                   []                0  ...  1  False
# 11                   []                0  ...  1  False
# 12                   []                0  ...  1  False
# 15                   []                0  ...  1  False
# 24                   []                0  ...  1  False
# 25                   []                0  ...  1  False
# 26                   []                0  ...  1  False
# 41                   []                0  ...  1  False
# 64                   []                0  ...  1  False
# 77                   []                0  ...  1  False
# 78                   []                0  ...  1  False
# 83                   []                0  ...  1  False
# 84                   []                0  ...  1  False
# 86                   []                0  ...  1  False
# 90                   []                0  ...  1  False
# 92                   []                0  ...  1  False
# 98                   []                0  ...  1  False
# 99                   []                0  ...  1  False
# 102                  []                0  ...  1  False
# 106                  []                0  ...  1  False
# 107                  []                0  ...  1  False
# 110                  []                0  ...  1  False
# 117                  []                0  ...  1  False
# 143                  []                0  ...  1  False
# 152                  []                0  ...  1  False
# 161                  []                0  ...  1  False
# 166                  []                0  ...  1  False
# ...                 ...              ...  ... ..    ...
# 49803                []                0  ...  1  False
# 49814                []                0  ...  1  False
# 49820                []                0  ...  1  False
# 49835                []                0  ...  1  False
# 49839                []                0  ...  1  False
# 49845                []                0  ...  1  False
# 49849                []                0  ...  1  False
# 49853                []                0  ...  1  False
# 49854                []                0  ...  1  False
# 49862                []                0  ...  1  False
# 49881                []                0  ...  1  False
# 49892                []                0  ...  1  False
# 49899                []                0  ...  1  False
# 49901                []                1  ...  1  False
# 49918                []                0  ...  1  False
# 49919                []                0  ...  1  False
# 49921                []                0  ...  1  False
# 49922                []                0  ...  1  False
# 49937                []                1  ...  1  False
# 49943                []                0  ...  1  False
# 49944                []                0  ...  1  False
# 49945                []                0  ...  1  False
# 49948                []                0  ...  1  False
# 49950                []                0  ...  1  False
# 49952                []                0  ...  1  False
# 49965                []                0  ...  1  False
# 49969                []                0  ...  1  False
# 49984                []                0  ...  1  False
# 49995                []                0  ...  1  False
# 49999                []                0  ...  1  False
#
# [8336 rows x 50 columns]

# %%
 #training on rowferrer
X = df_up['rawReferrer']
Y = df_up['Ret']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33)
cvec = CountVectorizer(stop_words='english').fit(X_train)
df_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
df_test=pd.DataFrame(cvec.transform(X_test).todense(), columns=cvec.get_feature_names())
a_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
a_test=pd.DataFrame(cvec.transform(X_test).todense(), columns=cvec.get_feature_names())

# %%
lr = LogisticRegression()
lr.fit(df_train, Y_train)
lr.score(df_test, Y_test)
# Out:
# 0.6368005492619293

# %%
lr = LogisticRegression(penalty='l2')
lr.fit(df_train, Y_train)
lr.score(df_test, Y_test)
# Out:
# 0.6368005492619293

# %%
dfna=df_up.dropna() #training on rowferrer
X = dfna['region']
Y = dfna['Ret']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33)
cvec = CountVectorizer(stop_words='english').fit(X_train)
df_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
df_test=pd.DataFrame(cvec.transform(X_test).todense(), columns=cvec.get_feature_names())
a_train=pd.DataFrame(cvec.transform(X_train).todense(), columns=cvec.get_feature_names())
a_test=pd.DataFrame(cvec.transform(X_test).todense(), columns=cvec.get_feature_names())

# %%
lr = LogisticRegression()
lr.fit(df_train, Y_train)
lr.score(df_test, Y_test)
# Out:
# 0.6213420787083754

# %%
#new approach with 2 variables
X1=dfna['rawReferrer']
X2=dfna['contentAuthor']
Y=dfna['Ret']
X1.size
# Out:
# 12012

# %%
X2.size
# Out:
# 12012

# %%
X1=cvec.fit_transform(X1)

# %%
X1
# Out:
# <12012x1480 sparse matrix of type '<class 'numpy.int64'>'
# 	with 13677 stored elements in Compressed Sparse Row format>

# %%
X2=cvec.fit_transform(X2)

# %%
X2
# Out:
# <12012x682 sparse matrix of type '<class 'numpy.int64'>'
# 	with 15893 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse import coo_matrix, vstack, hstack
X=hstack([X1, X2])

# %%
X
# Out:
# <12012x2162 sparse matrix of type '<class 'numpy.int64'>'
# 	with 29570 stored elements in COOrdinate format>

# %%
(X_train, X_test) = train_test_split(X)
(Y_train, Y_test) = train_test_split(Y)

# %%
X_train
# Out:
# <9009x2162 sparse matrix of type '<class 'numpy.int64'>'
# 	with 22187 stored elements in Compressed Sparse Row format>

# %%
X_test
# Out:
# <3003x2162 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7383 stored elements in Compressed Sparse Row format>

# %%
Y
# Out:
# 2        False
# 8        False
# 10       False
# 11       False
# 12       False
# 15       False
# 24       False
# 25       False
# 26       False
# 41       False
# 64       False
# 77       False
# 78       False
# 83       False
# 84       False
# 86       False
# 90       False
# 92       False
# 98       False
# 99       False
# 102      False
# 106      False
# 107      False
# 110      False
# 117      False
# 143      False
# 152      False
# 161      False
# 166      False
# 174      False
#          ...
# 28869     True
# 24539     True
# 42236     True
# 10098     True
# 4653      True
# 39388     True
# 29508     True
# 8530      True
# 27449     True
# 24704     True
# 11197     True
# 19001     True
# 30804     True
# 38935     True
# 11231     True
# 19001     True
# 35131     True
# 20330     True
# 1601      True
# 41606     True
# 2838      True
# 11093     True
# 22814     True
# 21071     True
# 11354     True
# 7808      True
# 4259      True
# 7844      True
# 42930     True
# 9011      True
# Name: Ret, Length: 12012, dtype: bool

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)
lr.score(X_test, Y_test)
# Out:
# 0.5907425907425907

# %%
#new approach with 3 variables

# %%
X1=df_up['rawReferrer']
X2=df_up['contentAuthor']
X3=df_up['contentSection']
Y=df_up['Ret']

# %%
X1=cvec.fit_transform(X1)
X2=cvec.fit_transform(X2)

# %%
X3=cvec.fit_transform(X3)

# %%
from scipy.sparse import coo_matrix, vstack, hstack
X=hstack([X1, X2, X3])

# %%
(X_train, X_test) = train_test_split(X)
(Y_train, Y_test) = train_test_split(Y)

# %%
lr = LogisticRegression(penalty='l2')
lr.fit(X_train, Y_train)
lr.score(X_test, Y_test)
# Out:
# 0.5060049852707909

# %%
 #4 descriptors
dfna=df_up.dropna()
X1=dfna['rawReferrer']
X2=dfna['contentAuthor']
X3=dfna['city']
X4=dfna['contentSection']
Y=dfna['Ret']
X1=cvec.fit_transform(X1)
X2=cvec.fit_transform(X2)
X3=cvec.fit_transform(X3)
X4=cvec.fit_transform(X4)

# %%
from scipy.sparse import coo_matrix, vstack, hstack
X=hstack([X1, X2, X3, X4])

# %%
(X_train, X_test) = train_test_split(X)
(Y_train, Y_test) = train_test_split(Y)

# %%
lr = LogisticRegression(penalty='l1')
lr.fit(X_train, Y_train)
lr.score(X_test, Y_test)
# Out:
# 0.5777555777555777

# %%
#5 
dfna=df_up.dropna()
X1=dfna['rawReferrer']
X2=dfna['contentAuthor']
X3=dfna['city']
X4=dfna['contentSection']
X5=dfna['browser']
Y=dfna['Ret']
X1=cvec.fit_transform(X1)
X2=cvec.fit_transform(X2)
X3=cvec.fit_transform(X3)
X4=cvec.fit_transform(X4)
X5=cvec.fit_transform(X5)
from scipy.sparse import coo_matrix, vstack, hstack
X=hstack([X1, X2, X3, X4, X5])

# %%
(X_train, X_test) = train_test_split(X)
(Y_train, Y_test) = train_test_split(Y)

# %%
lr = LogisticRegression(penalty='l1')
lr.fit(X_train, Y_train)
lr.score(X_test, Y_test)
# Out:
# 0.5864135864135864

# %%
#6
dfna=df_up.dropna()
X1=dfna['rawReferrer']
X2=dfna['contentAuthor']
X3=dfna['city']
X4=dfna['contentSection']
X5=dfna['browser']
X6=dfna['parsedReferrer']
Y=dfna['Ret']
X1=cvec.fit_transform(X1)
X2=cvec.fit_transform(X2)
X3=cvec.fit_transform(X3)
X4=cvec.fit_transform(X4)
X5=cvec.fit_transform(X5)
from scipy.sparse import coo_matrix, vstack, hstack
X=hstack([X1, X2, X3, X4, X5])

# %%
(X_train, X_test) = train_test_split(X)
(Y_train, Y_test) = train_test_split(Y)
lr = LogisticRegression()
lr.fit(X_train, Y_train)
lr.score(X_test, Y_test)
# Out:
# 0.5517815517815517

# %%
dfna=df_up.dropna()
X1=dfna['city']
X2=dfna['contentAuthor']
Y=dfna['Ret']
X1=cvec.fit_transform(X1)
X2=cvec.fit_transform(X2)
from scipy.sparse import coo_matrix, vstack, hstack
X=hstack([X1, X2])
(X_train, X_test) = train_test_split(X)
(Y_train, Y_test) = train_test_split(Y)
lr = LogisticRegression()
lr.fit(X_train, Y_train)
lr.score(X_test, Y_test)
# Out:
# 0.5554445554445554

# %%
dfna=df_up.dropna()
X1=dfna['city']
X2=dfna['contentAuthor']
Y=dfna['Ret']
X1=cvec.fit_transform(X1)
X2=cvec.fit_transform(X2)
from scipy.sparse import coo_matrix, vstack, hstack
X=hstack([X1, X2])
(X_train, X_test) = train_test_split(X)
(Y_train, Y_test) = train_test_split(Y)
lr = LogisticRegression(penalty='l1')
lr.fit(X_train, Y_train)
lr.score(X_test, Y_test)
# Out:
# 0.5700965700965701

# %%
Y_pred = lr.fit(X_train, Y_train).predict(X_test)
